# %%
# compare basic functions with numerical averages
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib widget
from scipy.special import erf
from ipywidgets import interactive, widgets
from IPython.display import display
from MFKSGaussClosure import g_avg, lbd_g_avg, rate_avg, lbd2_rate_avg

# random samples
n_mu = 50
n_samp = 10000
rndm = np.random.randn(n_mu, n_samp)

def g(lbd, mu, sig, kappa, k, eps, lbd_spl, r):
    return kappa * np.exp(-k * lbd) + eps * lbd

def lambda_g(lbd, mu, sig, kappa, k, eps, lbd_spl, r):
    return lbd * g(lbd, mu, sig, kappa, k, eps, lbd_spl, r)

def alpha(lbd, mu, sig, kappa, k, eps, lbd_spl, r):
    return np.maximum(0, r * (lbd - lbd_spl))

def lambda2_alpha(lbd, mu, sig, kappa, k, eps, lbd_spl, r):
    return lbd**2 * alpha(lbd, mu, sig, kappa, k, eps, lbd_spl, r)

# Function to plot
def plot_functions(sig, kappa, k, eps, lbd_spl, r, funcs_to_plot, log_y):
    x = np.linspace(0, 10, 5*n_mu)
    lbd_range_samp = rndm*sig + x[::5, None]
    lbd_range_samp[lbd_range_samp < 0] = np.nan

    args = (sig, kappa, k, eps, lbd_spl, r)
    
    plt.figure(figsize=(10, 6))
    if 'g_avg' in funcs_to_plot:
        plt.plot(x, g_avg(x, *args), label='g_avg')
        plt.scatter(x[::5], np.nanmean(g(lbd_range_samp, x[::5], *args), axis=-1), color='C1', label='g_avg_numeric')
    if 'lbd_g_avg' in funcs_to_plot:
        plt.plot(x, lbd_g_avg(x, *args), label='lbd_g_avg')
        plt.scatter(x[::5], np.nanmean(lambda_g(lbd_range_samp, x[::5], *args), axis=-1), color='C1',label='lbd_g_avg_numeric')
    if 'rate_avg' in funcs_to_plot:
        plt.plot(x, rate_avg(x, *args), label='rate_avg')
        plt.scatter(x[::5], np.nanmean(alpha(lbd_range_samp, x[::5], *args), axis=-1), color='C1',label='rate_avg_numeric')
    if 'lbd2_rate_avg' in funcs_to_plot:
        plt.plot(x, lbd2_rate_avg(x, *args), label='lbd2_rate_avg')
        plt.scatter(x[::5], np.nanmean(lambda2_alpha(lbd_range_samp, x[::5], *args), axis=-1), color='C1',label='lbd2_rate_avg_numeric')
    
    if log_y:
        plt.yscale('log')
        
    plt.legend()
    plt.xlabel('mu')
    plt.ylabel('Function Value')
    plt.title('Interactive Plot of Functions')
    plt.grid(True)
    plt.show()

# Define sliders and checkboxes
sig_slider = widgets.FloatSlider(value=1, min=0.1, max=5, step=0.1, description='sig')
kappa_slider = widgets.FloatSlider(value=1, min=0.1, max=5, step=0.1, description='kappa')
k_slider = widgets.FloatSlider(value=1, min=0.1, max=5, step=0.1, description='k')
eps_slider = widgets.FloatSlider(value=0.0, min=0., max=0.1, step=0.001, description='eps')
lbd_spl_slider = widgets.FloatSlider(value=7, min=0.1, max=10, step=0.1, description='lbd_spl')
r_slider = widgets.FloatSlider(value=1, min=0.1, max=5, step=0.1, description='r')
funcs_checkboxes = widgets.SelectMultiple(
    options=['g_avg', 'lbd_g_avg', 'rate_avg', 'lbd2_rate_avg'],
    value=['g_avg'],
    description='Functions'
)
log_y_toggle = widgets.ToggleButton(value=False, description='Log y-axis', button_style='')

# Create interactive plot
interactive_plot = interactive(plot_functions, 
                               sig=sig_slider, 
                               kappa=kappa_slider, 
                               k=k_slider, 
                               eps=eps_slider, 
                               lbd_spl=lbd_spl_slider, 
                               r=r_slider,
                               funcs_to_plot=funcs_checkboxes,
                               log_y=log_y_toggle)

display(interactive_plot)
# Out:
# interactive(children=(FloatSlider(value=1.0, description='sig', max=5.0, min=0.1), FloatSlider(value=1.0, desc…

# %%
# Investigate mu, sig  prime and their approximations
from MFKSGaussClosure import mu_prime, sig_prime, gauss, erfc
plt.close('all')
def mu_prime_approx(mu, sig, kappa, k, eps, lbd_spl, r):
    args = (mu, sig, kappa, k, eps, lbd_spl, r)
    return - mu * (0.5 * rate_avg(*args) + 0 * gauss(mu, sig) * (g_avg(*args) - kappa))

def sig_prime_approx(mu, sig, kappa, k, eps, lbd_spl, r):
    args = (mu, sig, kappa, k, eps, lbd_spl, r)
    mu_tilde = mu - k * sig**2
    return kappa * k * sig * np.exp(-k * mu + k**2 * sig**2 / 2) * erfc(- mu_tilde / sig) / erfc(- mu / sig) - eps * sig \
        + sig * gauss(mu, sig) / erfc(- mu / sig) * (eps * mu + kappa * np.exp(-k * mu + k**2 * sig**2 / 2) * erfc(- mu_tilde / sig) / erfc(- mu / sig) - kappa) \
        - 0.5*(mu**2 - sig**2) * mu_prime(*args) / mu / sig

def sig_prime_approx2(mu, sig, kappa, k, eps, lbd_spl, r):
    args = (mu, sig, kappa, k, eps, lbd_spl, r)
    mu_tilde = mu - k * sig**2
    return kappa * k * sig * np.exp(-k * mu + k**2 * sig**2 / 2) * erfc(- mu_tilde / sig) - eps * sig \
        + sig * gauss(mu, sig) * (eps * mu * (1 + mu**2/sig**2) / 2 + kappa * np.exp(-k * mu + k**2 * sig**2 / 2) * erfc(- mu_tilde / sig) * (1/2 + k * sig**2 / mu + mu**2/sig**2/2) - kappa * (1 + mu**2/sig**2)/2)

def sig_prime_approx3(mu, sig, kappa, k, eps, lbd_spl, r):
    args = (mu, sig, kappa, k, eps, lbd_spl, r)
    mu_tilde = mu - k * sig**2
    return sig * gauss(mu, sig) * (eps * mu * (1 + mu**2/sig**2) / 2 + kappa * np.exp(-k * mu + k**2 * sig**2 / 2) * erfc(- mu_tilde / sig) * (1/2 + k * sig**2 / mu + mu**2/sig**2/2) - kappa * (1 + mu**2/sig**2)/2)

def sig_prime_approx4(mu, sig, kappa, k, eps, lbd_spl, r):
    args = (mu, sig, kappa, k, eps, lbd_spl, r)
    mu_tilde = mu - k * sig**2
    return sig * gauss(mu, sig) * (eps * mu * (1 + mu**2/sig**2) / 2 - kappa * (1 + mu**2/sig**2)/2)

# Function to plot
def plot_functions(mu, sig, kappa, k, eps, lbd_spl, r, funcs_to_plot, log_y):
    x = np.linspace(0, 40, 5*n_mu)
    y = np.linspace(0, 10, 5*n_mu)
    args = (kappa, k, eps, lbd_spl, r)
    
    plt.figure(figsize=(10, 6))
    
    if 'mu' in funcs_to_plot:
        # plt.axvspan(0, sig, color='k', alpha=0.3, label='mean too small')
        plt.plot(x, mu_prime(x, sig, *args), label='mu_prime')
        plt.plot(x, sig_prime(x, sig, *args), label='sig_prime')
        plt.plot(x, mu_prime_approx(x, sig, *args), label='mu_prime_approx')
        plt.plot(x, sig_prime_approx(x, sig, *args), label='sig_prime_approx')
        plt.plot(x, sig_prime_approx2(x, sig, *args), label='sig_prime_approx')
        plt.plot(x, sig_prime_approx3(x, sig, *args), label='sig_prime_approx')
        plt.plot(x, sig_prime_approx4(x, sig, *args), label='sig_prime_approx')

    if 'sig' in funcs_to_plot:
        # plt.axvspan(mu, np.max(y), color='k', alpha=0.3, label='sig too big')
        plt.plot(y, mu_prime(mu, y, *args), label='mu_prime')
        plt.plot(y, sig_prime(mu, y, *args), label='sig_prime')
        # plt.plot(y, mu_prime_approx(mu, y, *args), label='mu_prime_approx')
        # plt.plot(x, lbd_g_avg_approx(x, *args), label='lbd_g_avg_approx')
    
    if log_y:
        plt.yscale('symlog', linthreshy=1e-2)
        
    plt.legend()
    plt.ylabel('Function Value')
    plt.title('Interactive Plot of Functions')
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# Define sliders and checkboxes
mu_slider = widgets.FloatSlider(value=1, min=0.1, max=40, step=0.1, description='mu', continuous_update=False)
sig_slider = widgets.FloatSlider(value=1, min=0.1, max=5, step=0.1, description='sig', continuous_update=False)
kappa_slider = widgets.FloatSlider(value=1, min=0.1, max=5, step=0.1, description='kappa', continuous_update=False)
k_slider = widgets.FloatSlider(value=1, min=0.1, max=5, step=0.1, description='k', continuous_update=False)
eps_slider = widgets.FloatSlider(value=0.0, min=0., max=0.1, step=0.001, description='eps', continuous_update=False)
lbd_spl_slider = widgets.FloatSlider(value=7, min=0.1, max=10, step=0.1, description='lbd_spl', continuous_update=False)
r_slider = widgets.FloatSlider(value=1, min=0.0, max=5, step=0.1, description='r', continuous_update=False)
funcs_checkboxes = widgets.SelectMultiple(
    options=['mu', 'sig'],
    value=['mu'],
    description='Functions'
)
log_y_toggle = widgets.ToggleButton(value=False, description='SymLog y-axis', button_style='')

# Create interactive plot
interactive_plot = interactive(plot_functions, 
                               mu=mu_slider, 
                               sig=sig_slider, 
                               kappa=kappa_slider, 
                               k=k_slider, 
                               eps=eps_slider, 
                               lbd_spl=lbd_spl_slider, 
                               r=r_slider, 
                               funcs_to_plot=funcs_checkboxes,
                               log_y=log_y_toggle)

display(interactive_plot)
# Out:
# interactive(children=(FloatSlider(value=1.0, continuous_update=False, description='mu', max=40.0, min=0.1), Fl…

# %%
# vanilla gaussian streamline
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
# %matplotlib widget
from matplotlib.widgets import Slider
from ipywidgets import interact, FloatSlider
from MFKSGaussClosure import mu_sig_prime, mu_prime, sig_prime
from scipy.integrate import solve_ivp

# Function to create the streamline plot
def plot_vector_field(kappa, k, eps, lbd_spl, r):
    # Create a grid of points
    x = np.linspace(0, 100, 100)
    y = np.linspace(0.001, 10.5, 100)
    X, Y = np.meshgrid(x, y)
    U, V = mu_sig_prime((X, Y), kappa, k, eps, lbd_spl, r)
    # mask = X - 2*Y < 0
    # U[mask] = V[mask] = np.nan   

    fig = plt.figure(figsize=(10, 8))
    strm = plt.streamplot(X, Y, U, V, color=np.sqrt(U**2 + V**2), density=1.6, cmap='winter', norm=LogNorm(1e-7, 1e-1))

    fig.colorbar(strm.lines)
    plt.xlim(np.min(x),np.max(x))
    plt.ylim(np.min(y),np.max(y))
    plt.xlabel('mu')
    plt.ylabel('sig')
    plt.title('Streamline plot of the vector field')
    plt.grid()
    plt.tight_layout()
    plt.show()

# Interactive sliders
interact(plot_vector_field,
         kappa=FloatSlider(min=0, max=4, step=0.1, value=1.2, description='kappa', continuous_update=False),
         k=FloatSlider(min=0, max=4, step=0.1, value=1, description='k', continuous_update=False),
         eps=FloatSlider(min=0, max=1e-6, step=1e-8, value=0, description='eps', continuous_update=False, readout_format='.1e'),
         lbd_spl=FloatSlider(min=2, max=100, step=1, value=50, description='lbd_spl', continuous_update=False),
         r=FloatSlider(min=0, max=1e-1, step=1e-5, value=1e-3, description='r', continuous_update=False, readout_format='.1e'))
# Out:
# interactive(children=(FloatSlider(value=1.2, continuous_update=False, description='kappa', max=4.0), FloatSlid…
# <function __main__.plot_vector_field(kappa, k, eps, lbd_spl, r)>

# %%
# nullcline utility functions & how they work
import numpy as np
from scipy.optimize import fsolve

def find_roots_rich(func, array, args):
    # evaluate on array 
    func_array = func(array, *args)
    
    # find indices where sign change
    sign_change_inds = np.where(func_array[1:]*func_array[:-1] < 0.0)
        
    # use those as starting points for fsolve 
    roots = fsolve(func, array[sign_change_inds], args=args, full_output=True)

    # return roots in case of success
    if roots[-2]:
        return roots[0]
    else:
        return [None]
    
def scatter_flex(fig, ax, x_array, y_array, *args, **kwargs):
    try:
        flattened_y = np.concatenate(y_array)
        repeated_x = np.repeat(x_array, [len(y) for y in y_array])
        return ax.scatter(repeated_x, flattened_y, *args, **kwargs)
    except:
        flattened_x = np.concatenate(x_array)
        repeated_y = np.repeat(y_array, [len(x) for x in x_array])
        return ax.scatter(flattened_x, repeated_y, *args, **kwargs)

if False:
    # import matplotlib.pyplot as plt
    # %matplotlib widget
    test_fct = lambda x, a, b: np.sin(x) + 1 - np.exp(-a*x)
    x_array = np.linspace(0, 30, 500)
    fig, ax = plt.subplots()
    scatter_flex(fig, ax, np.linspace(0, 3), [find_roots_rich(test_fct, x_array, (np.linspace(0, 3)[i], 3)) for i in range(50)], color='r')
#     scatter_flex(fig, ax, [find_roots_rich(test_fct, x_array, np.linspace(0, 3)[i], 3) for i in range(50)], np.linspace(0, 3), color='r')

# %%
# reparameterizion functions
def peak_mass(Drho, Dc, T):
    return np.sqrt(12 * Drho * Dc / T)

def _lbd_spl_eps(eps):
    if eps == 0.0:
        return np.inf 
    else:
        return np.exp(1.13734914) * eps**(-0.3579829)
lbd_spl_eps = np.vectorize(_lbd_spl_eps)

def reparameterize(Drho, Dc, T, epsilon, r):
    M = peak_mass(Drho, Dc, T)
    kappa = 1 / (1 / 4 / np.sqrt(Dc) + 1 / M / T)
    k = 1 / np.sqrt(Dc) 
    eps = 4 * epsilon * np.exp(-T * M / 2 / Drho / np.sqrt(Dc))
    lbd_spl = lbd_spl_eps(epsilon)
    return kappa, k, eps, lbd_spl, r

# %%
# compare basic functions with numerical averages (reparameterized)
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib widget
from scipy.special import erf
from ipywidgets import interactive, widgets, interact, FloatSlider, IntSlider, Layout
from IPython.display import display
from MFKSGaussClosure import g_avg, lbd_g_avg, rate_avg, lbd2_rate_avg

# random samples
n_mu = 50
n_samp = 10000
rndm = np.random.randn(n_mu, n_samp)
def g(lbd, mu, sig, kappa, k, eps, lbd_spl, r):
    return kappa * np.exp(-k * lbd) + eps * lbd

def lambda_g(lbd, mu, sig, kappa, k, eps, lbd_spl, r):
    return lbd * g(lbd, mu, sig, kappa, k, eps, lbd_spl, r)

def alpha(lbd, mu, sig, kappa, k, eps, lbd_spl, r):
    return np.maximum(0, r * (lbd - lbd_spl))

def lambda2_alpha(lbd, mu, sig, kappa, k, eps, lbd_spl, r):
    return lbd**2 * alpha(lbd, mu, sig, kappa, k, eps, lbd_spl, r)

# Function to plot
def plot_functions(Drho, Dc, T, epsilon, r, xmax, dx, mu, sig, funcs_to_plot, log_y):

    kappa, k, eps, lbd_spl, r = reparameterize(Drho, Dc, T, epsilon, r)

    x = np.linspace(0, 10, 5*n_mu)
    args = (sig, kappa, k, eps, lbd_spl, r)
    lbd_range_samp = rndm*sig + x[::5, None]
    lbd_range_samp[lbd_range_samp < 0] = np.nan
    
    plt.figure(figsize=(10, 6))
    plt.axvspan(0, sig, color='k', alpha=0.3, label='mean too small')
    if 'g_avg' in funcs_to_plot:
        plt.plot(x, g_avg(x, *args), label='g_avg')
        plt.plot(x[::5], np.nanmean(g(lbd_range_samp, x[::5],*args), axis=-1), '-o', label='g_avg_numeric')
        # plt.plot(x, g_avg_approx(x, *args), label='g_avg_approx')
    if 'lbd_g_avg' in funcs_to_plot:
        plt.plot(x, lbd_g_avg(x, *args), label='lbd_g_avg')
        plt.plot(x[::5], np.nanmean(lambda_g(lbd_range_samp, x[::5],*args), axis=-1), '-o', label='lbd_g_avg_numeric')
        # plt.plot(x, lbd_g_avg_approx(x, *args), label='lbd_g_avg_approx')
    if 'rate_avg' in funcs_to_plot:
        plt.plot(x, rate_avg(x, *args), label='rate_avg')
        plt.plot(x[::5], np.nanmean(alpha(lbd_range_samp, x[::5],*args), axis=-1), '-o', label='rate_avg_numeric')
        # plt.plot(x, rate_avg_approx(x, *args), label='rate_avg_approx')
    if 'lbd2_rate_avg' in funcs_to_plot:
        plt.plot(x, lbd2_rate_avg(x, *args), label='lbd2_rate_avg')
        plt.plot(x[::5], np.nanmean(lambda2_alpha(lbd_range_samp, x[::5],*args), axis=-1), '-o', label='lbd2_rate_avg_numeric')
        # plt.plot(x, lbd2_rate_avg_approx(x, *args), label='lbd2_rate_avg_approx')
    
    if log_y:
        plt.yscale('log')
        
    plt.legend()
    plt.xlabel('mu')
    plt.ylabel('Function Value')
    plt.title('Interactive Plot of Functions')
    plt.grid(True)
    plt.show()

# Define sliders and checkboxes
# Create interactive sliders
Drho_slider = FloatSlider(value=0.1, min=0.01, max=1.0, step=0.01, description='D_rho:', layout=Layout(width='500px'), continuous_update=False)
Dc_slider = FloatSlider(value=1.0, min=0.1, max=2.0, step=0.1, description='D_c:', layout=Layout(width='500px'), continuous_update=False)
T_slider = FloatSlider(value=5.0, min=0.5, max=10.0, step=0.1, description='T:', layout=Layout(width='500px'), continuous_update=False)
epsilon_slider = FloatSlider(value=1e-2, min=0, max=1e-1, step=1e-3, description='epsilon:', readout_format='.2e', layout=Layout(width='500px'), continuous_update=False)
r_slider = FloatSlider(value=0.04, min=0.001, max=1.0, step=1e-3, description='r:', readout_format='.1e', layout=Layout(width='500px'), continuous_update=False)
xmax_slider = IntSlider(value=30, min=10, max=50, step=1, description='xmax:', layout=Layout(width='500px'), continuous_update=False)
dx_slider = FloatSlider(value=1e-3, min=1e-4, max=1e-2, step=1e-4, description='dx:', readout_format='.1e', layout=Layout(width='500px'), continuous_update=False)
mu_slider = FloatSlider(value=6, min=2.0, max=8.0, step=0.1, description='mu_ini:', layout=Layout(width='500px'), continuous_update=False)
sig_slider = FloatSlider(value=1.0, min=0.1, max=3.0, step=0.1, description='sig_ini:', layout=Layout(width='500px'), continuous_update=False)
funcs_checkboxes = widgets.SelectMultiple(
    options=['g_avg', 'lbd_g_avg', 'rate_avg', 'lbd2_rate_avg'],
    value=['g_avg'],
    description='Functions'
)
log_y_toggle = widgets.ToggleButton(value=False, description='Log y-axis', button_style='')

# Create interactive plot
interactive_plot = interactive(plot_functions, 
                               Drho=Drho_slider,
                               Dc=Dc_slider,
                               T=T_slider,
                               epsilon=epsilon_slider,
                               r=r_slider,
                               xmax=xmax_slider,
                               dx=dx_slider,
                               mu=mu_slider,
                               sig=sig_slider,
                               funcs_to_plot=funcs_checkboxes,
                               log_y=log_y_toggle)

display(interactive_plot)
# Out:
# interactive(children=(FloatSlider(value=0.1, continuous_update=False, description='D_rho:', layout=Layout(widt…

# %%
# Investigate mu, sig  prime and their approximations (reparametereized)
from ipywidgets import Layout, IntSlider

def plot_functions(Drho, Dc, T, epsilon, r, xmax, dx, mu, sig, funcs_to_plot, log_y):
    x = np.linspace(0, xmax, 5*n_mu)
    y = np.linspace(0, xmax/3, 5*n_mu)
    
    kappa, k, eps, lbd_spl, r = reparameterize(Drho, Dc, T, epsilon, r)
    
    args = (kappa, k, eps, lbd_spl, r)
    
    plt.figure(figsize=(10, 6))
    
    if 'mu' in funcs_to_plot:
        plt.axvspan(0, sig, color='k', alpha=0.3, label='mean too small')
        plt.plot(x, mu_prime(x, sig, *args), label='mu_prime')
        plt.plot(x, sig_prime(x, sig, *args), label='sig_prime')
        plt.plot(x, sig * k * kappa * np.exp(-k * x) - sig * eps, 'k--', label='- sig g prime')
        plt.plot(x, sig * k * kappa * np.exp(-k * x) - sig * eps - 0.5 * (sig**2 - x**2) *  kappa * (np.exp(-k * x) * (1 + 0.5 * sig**2 * k**2) - 1) * gauss(x, sig) / sig, 'k--', label='- sig g prime new')
        plt.plot(x, - x * kappa * (np.exp(-k * x) - 1) * gauss(x, sig) , 'r--', label='mu prime approx')
        # plt.vlines([lbd_spl_eps(epsilon)], [-1], [1], 'k', label='lambda split')
        plt.axvspan(min(x[sig * k * kappa * np.exp(-k * x) - sig * eps < 0]), lbd_spl_eps(epsilon), color='r', alpha=0.1, label='stable')
        # plt.plot(x, mu_prime_approx(x, sig, *args), label='mu_prime_approx')
        # plt.plot(x, g_avg_approx(x, *args), label='g_avg_approx')
    if 'sig' in funcs_to_plot:
        plt.axvspan(mu, np.max(y), color='k', alpha=0.3, label='sig too big')
        plt.plot(y, sig_prime(mu, y, *args), label='sig_prime')
        plt.plot(y, mu_prime(mu, y, *args), label='mu_prime')
        # plt.plot(y, mu_prime_approx(mu, y, *args), label='mu_prime_approx')
        # plt.plot(x, lbd_g_avg_approx(x, *args), label='lbd_g_avg_approx')
    
    if log_y:
        plt.yscale('symlog', linthreshy=1e-2)
        
    plt.legend()
    plt.ylabel('Function Value')
    plt.title('Interactive Plot of Functions')
    plt.grid(True)
    plt.show()

# Define sliders and checkboxes
Drho_slider = FloatSlider(value=0.1, min=0.01, max=1.0, step=0.01, description='D_rho:', layout=Layout(width='500px'), continuous_update=False)
Dc_slider = FloatSlider(value=1.0, min=0.1, max=2.0, step=0.1, description='D_c:', layout=Layout(width='500px'), continuous_update=False)
T_slider = FloatSlider(value=5.0, min=0.5, max=10.0, step=0.1, description='T:', layout=Layout(width='500px'), continuous_update=False)
epsilon_slider = FloatSlider(value=1e-3, min=0, max=1e-1, step=1e-4, description='epsilon:', readout_format='.2e', layout=Layout(width='500px'), continuous_update=False)
r_slider = FloatSlider(value=0.04, min=0.001, max=1.0, step=1e-3, description='r:', readout_format='.1e', layout=Layout(width='500px'), continuous_update=False)
xmax_slider = IntSlider(value=30, min=10, max=50, step=1, description='xmax:', layout=Layout(width='500px'), continuous_update=False)
dx_slider = FloatSlider(value=1e-3, min=1e-4, max=1e-2, step=1e-4, description='dx:', readout_format='.1e', layout=Layout(width='500px'), continuous_update=False)
mu_slider = FloatSlider(value=6, min=2.0, max=8.0, step=0.1, description='mu:', layout=Layout(width='500px'), continuous_update=False)
sig_slider = FloatSlider(value=0.2, min=0.01, max=4.0, step=0.01, description='sig:', layout=Layout(width='500px'), continuous_update=False)
funcs_checkboxes = widgets.SelectMultiple(
    options=['mu', 'sig'],
    value=['mu'],
    description='Functions'
)
log_y_toggle = widgets.ToggleButton(value=False, description='SymLog y-axis', button_style='')

# Create interactive plot
interactive_plot = interactive(plot_functions, 
                               Drho=Drho_slider,
                               Dc=Dc_slider,
                               T=T_slider,
                               epsilon=epsilon_slider,
                               r=r_slider,
                               xmax=xmax_slider,
                               dx=dx_slider,
                               mu=mu_slider,
                               sig=sig_slider,
                               funcs_to_plot=funcs_checkboxes,
                               log_y=log_y_toggle)

display(interactive_plot)
# Out:
# interactive(children=(FloatSlider(value=0.1, continuous_update=False, description='D_rho:', layout=Layout(widt…

# %%
# streamlines, nullclines & their approximations - interactive 
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook
from matplotlib.colors import LogNorm
from matplotlib.widgets import Slider
from ipywidgets import interact, FloatSlider, Layout
from MFKSGaussClosure import mu_sig_prime, mu_prime, sig_prime, lbd2_rate_avg, rate_avg, erfc, gauss
from scipy.integrate import solve_ivp
from scipy.optimize import fsolve
import warnings
import matplotlib.collections
warnings.filterwarnings('ignore', category=RuntimeWarning)

def sig_term_r1(mu, sig, kappa, k, eps, lbd_spl, r):
    eps = 0.0
    args = (mu, sig, kappa, k, eps, lbd_spl, r)
    res = - 1/8 * lbd2_rate_avg(*args)
    return res / sig
    
def sig_term_r2(mu, sig, kappa, k, eps, lbd_spl, r):
    eps = 0.0
    args = (mu, sig, kappa, k, eps, lbd_spl, r)
    res = 0.25 * mu**2 * rate_avg(*args)
    return res / sig
    
# Function to create the streamline plot
def plot_vector_field(Drho, Dc, T, epsilon, lbd_spl, r):
    # Create a grid of points
    x = np.linspace(0, 50, 100)
    y = np.linspace(0.001, 6, 100)
    X, Y = np.meshgrid(x, y)
    kappa, k, eps, _, r = reparameterize(Drho, Dc, T, epsilon, r)
    U, V = mu_sig_prime((X, Y), kappa, k, eps, lbd_spl, r)
    
    print(f"µ∞ = {kappa/eps:.1e} (location of epsilon induced µ-nullcline)")
    mu0 = -1/k * np.log(eps/k/kappa)
    print(f"µ0 = {mu0:.2f} (location of maximum of v_M)")    

    plt.close('all')
    fig, ax = plt.subplots(1, figsize=(10, 8))
    strm = ax.streamplot(X, Y, U, V, color=np.sqrt(U**2 + V**2), density=1.6, cmap='winter', norm=LogNorm(1e-16, 1e-1))
#     strm = ax.streamplot(X, Y, U, V, color='grey')
    fig.colorbar(strm.lines)

    # Plot nullclines and other lines
    lines = []
    labels = []
    initially_invis = []
    
    line1, = ax.plot(mu0 + k * y**2 / 2, y, 'b--', label='$\sigma\' = 0$ (analytic approx)')
    initially_invis.append(line1)
    lines.append(line1)
    labels.append('$\sigma\' = 0$ (analytic approx)')
    
    _x = 2 * y**2 / lbd_spl**2
    line4, = ax.plot(lbd_spl/2 * (1 + _x * np.log(4 * kappa/_x/r/y**2))/(1 + _x), y, 'r--', label='$\mu\' = 0$ (analytic approx)')
    lines.append(line4)
    labels.append('$\mu\' = 0$ (analytic approx)')
    
    line5, = ax.plot(x, np.sqrt(x/k), 'k--', label='$\mu = k \sigma^2$')
    initially_invis.append(line5)
    lines.append(line5)
    labels.append('$\mu = k \sigma^2$')

    line6, = ax.plot(np.sqrt(lbd_spl**2/2 + 2 * y**2), y, 'g--', label='$\sigma^2 = \mu^2/2 - \Lambda_{spl}^2/4$')
    # initially_invis.append(line6)
    lines.append(line6)
    labels.append('$\sigma^2 = \mu^2/2 - \Lambda_{spl}^2/4$')

    sigma_prime_pts = scatter_flex(fig, ax, x, [find_roots_rich(lambda y: sig_prime(xi, y, kappa, k, eps, lbd_spl, r), y, ()) for xi in x], label='$\sigma\' = 0, \epsilon > 0$')
    lines.append(sigma_prime_pts)
    labels.append('$\sigma\' = 0, \epsilon > 0$')
    
#     sigma_prime_app1_pts = scatter_flex(fig, ax, x, [find_roots_rich(lambda y: y**2 * k * erfc(-(xi-k*y**2)/y)/gauss(xi-k*y**2, y) - 0.5*(xi**2 + y**2) + eps/kappa * y**2 * xi * (y**2/xi**2 + 1) - y**2 * eps / kappa / gauss(xi, y), y, ()) for xi in x], label='$\sigma\' = 0, \epsilon > 0$ (approx)')
#     initially_invis.append(sigma_prime_app1_pts)
#     lines.append(sigma_prime_app1_pts)
#     labels.append('$\sigma\' = 0, \epsilon > 0$ (approx)')
    
#     sigma_prime_app2_pts = scatter_flex(fig, ax, x, [find_roots_rich(lambda y: sig_prime(xi, y, kappa, k, eps, lbd_spl, 0.0) + sig_term_r2(xi, y, kappa, k, eps, lbd_spl, r), y, ()) for xi in x], label='$\sigma\' = 0, \epsilon > 0$ (approx2)')
#     initially_invis.append(sigma_prime_app2_pts)
#     lines.append(sigma_prime_app2_pts)
#     labels.append('$\sigma\' = 0, \epsilon > 0$ (approx2)')
    
    mu_prime_pts = scatter_flex(fig, ax, [fsolve(lambda x: mu_prime(x, yi, kappa, k, eps, lbd_spl, r), k*yi**2) for yi in y], y, marker='+', label='$\mu\' = 0$')
    lines.append(mu_prime_pts)
    labels.append('$\mu\' = 0$')
    
    sigma_prime_eps0_pts = scatter_flex(fig, ax, x, [find_roots_rich(lambda y: sig_prime(xi, y, kappa, k, 0.0, lbd_spl, r), y, ()) for xi in x], label='$\sigma\' = 0, \epsilon = 0$')
    initially_invis.append(sigma_prime_eps0_pts)
    lines.append(sigma_prime_eps0_pts)
    labels.append('$\sigma\' = 0, \epsilon = 0$')

#     sigma_prime_eps0_app1_pts = scatter_flex(fig, ax, x, [find_roots_rich(lambda y: y**2 * k * erfc(-(xi-k*y**2)/y)/gauss(xi-k*y**2, y) - 0.5*(xi**2 + y**2), y, ()) for xi in x], label='$\sigma\' = 0, \epsilon = 0$ (approx)')
#     initially_invis.append(sigma_prime_eps0_app1_pts)
#     lines.append(sigma_prime_eps0_app1_pts)
#     labels.append('$\sigma\' = 0, \epsilon = 0$ (approx)')

    mu_prime_eps0_pts = scatter_flex(fig, ax, [fsolve(lambda x: mu_prime(x, yi, kappa, k, 0.0, lbd_spl, r), k*yi**2) for yi in y], y, marker='+', label='$\mu\' = 0 (\epsilon = 0)$')
    initially_invis.append(mu_prime_eps0_pts)
    lines.append(mu_prime_eps0_pts)
    labels.append('$\mu\' = 0 (\epsilon = 0)$')

#     sig_prime_push_pts = scatter_flex(fig, ax, x, [find_roots_rich(lambda y: lbd_spl**2 * y / (lbd_spl - xi)**2 * np.exp(-(lbd_spl-xi)**2/2/y**2) - 2 * eps * np.sqrt(2*np.pi) / r, y, ()) for xi in x], label='wish')
#     initially_invis.append(sig_prime_push_pts)
#     lines.append(sig_prime_push_pts)
#     labels.append('wish')


    ax.set_xlim(np.min(x), np.max(x))
    ax.set_ylim(np.min(y), np.max(y))
    ax.set_xlabel('mu')
    ax.set_ylabel('sig')
    ax.set_title('Streamline plot of the vector field')
    ax.grid()

    # Add legend and make it interactive
    leg = ax.legend(fancybox=True, shadow=True)
    _objs = leg.get_lines() + leg.findobj(matplotlib.collections.PathCollection)
    map_legend_to_ax = {legend_line: line for legend_line, line in zip(_objs, lines)}

    for legend_line in _objs:
        legend_line.set_picker(5)  # Enable picking on the legend line

    def on_pick(event):
        # On the pick event, find the original line corresponding to the legend
        # proxy line, and toggle its visibility.
        legend_line = event.artist
    
        # Do nothing if the source of the event is not a legend line.
        if legend_line not in map_legend_to_ax:
            print('here')
            return
    
        plot_element = map_legend_to_ax[legend_line]
        visible = not plot_element.get_visible()
        plot_element.set_visible(visible)
        # Change the alpha on the line in the legend, so we can see what lines
        # have been toggled.
        legend_line.set_alpha(1.0 if visible else 0.2)
        fig.canvas.draw()
    fig.canvas.mpl_connect('pick_event', on_pick)
    leg.set_draggable(True)

    for el in initially_invis:
        el.set_visible(False)
    
    plt.tight_layout()
    plt.show()


# Interactive sliders
Drho_slider = FloatSlider(value=0.1, min=0.01, max=1.0, step=0.01, description='D_rho:', layout=Layout(width='500px'), continuous_update=False)
Dc_slider = FloatSlider(value=1.0, min=0.1, max=2.0, step=0.1, description='D_c:', layout=Layout(width='500px'), continuous_update=False)
T_slider = FloatSlider(value=5.0, min=0.5, max=10.0, step=0.1, description='T:', layout=Layout(width='500px'), continuous_update=False)
epsilon_slider = FloatSlider(value=1e-6, min=0, max=1e-1, step=1e-6, description='epsilon:', readout_format='.2e', layout=Layout(width='500px'), continuous_update=False)
lbd_spl_slider = FloatSlider(value=3e1, min=0, max=1e2, step=1, description='lbd_spl:', readout_format='.2e', layout=Layout(width='500px'), continuous_update=False)
r_slider = FloatSlider(value=1e-9, min=0, max=1e-1, step=1e-6, description='r:', readout_format='.1e', layout=Layout(width='500px'), continuous_update=False)

# Create interactive plot
interactive_plot = interact(plot_vector_field, 
                            Drho=Drho_slider,
                            Dc=Dc_slider,
                            T=T_slider,
                            epsilon=epsilon_slider,
                            lbd_spl=lbd_spl_slider,
                            r=r_slider)

display(interactive_plot)
# Out:
# interactive(children=(FloatSlider(value=0.1, continuous_update=False, description='D_rho:', layout=Layout(widt…
# <function __main__.plot_vector_field(Drho, Dc, T, epsilon, lbd_spl, r)>

# %%
# compare analytic derivatives with numerical derivatives
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib widget
from ipywidgets import interactive, widgets
from IPython.display import display
from MFKSGaussClosure import *#gauss_spl, erfc_spl, erfc_til, g_avg, lbd_g_avg, rate_avg, lbd2_rate_avg, f1, f2, dmu_gauss_spl, dmu_erfc_spl, dmu_erfc_til, dmu_g_avg, dmu_lbd_g_avg, dmu_rate_avg, dmu_lbd2_rate_avg, dmu_f1, dmu_f2, dsig_gauss_spl, dsig_erfc_spl, dsig_erfc_til, dsig_g_avg, dsig_lbd_g_avg, dsig_rate_avg, dsig_lbd2_rate_avg, dsig_f1, dsig_f2

mus = np.linspace(0, 20, 10000)
sigs = np.linspace(0.001, 12, 5000)

funcs_array = [gauss_spl, erfc_spl, erfc_til, g_avg, lbd_g_avg, rate_avg, lbd2_rate_avg, f1, f2]
dmu_funcs_array = [dmu_gauss_spl, dmu_erfc_spl, dmu_erfc_til, dmu_g_avg, dmu_lbd_g_avg, dmu_rate_avg, dmu_lbd2_rate_avg, dmu_f1, dmu_f2]
dsig_funcs_array = [dsig_gauss_spl, dsig_erfc_spl, dsig_erfc_til, dsig_g_avg, dsig_lbd_g_avg, dsig_rate_avg, dsig_lbd2_rate_avg, dsig_f1, dsig_f2]

# Function to plot
def plot_functions(kappa, k, eps, lbd_spl, r, mu0, sig0, log_y):
    args = (kappa, k, eps, lbd_spl, r)

    plt.close('all')
    plt.figure(figsize=(10, 6))
    for i in range(len(funcs_array)):
        func = funcs_array[i]
        dmu_func = dmu_funcs_array[i]
        dsig_func = dsig_funcs_array[i]
        plt.plot(mus, np.abs((np.gradient(func(mus, sig0, *args), mus) - dmu_func(mus, sig0, *args))/np.gradient(func(mus, sig0, *args), mus)), label=f'{dmu_func.__name__}(mu)')
        plt.plot(sigs, np.abs((np.gradient(func(mu0, sigs, *args), sigs) - dsig_func(mu0, sigs, *args))/np.gradient(func(mu0, sigs, *args), sigs)), '--',label=f'{dsig_func.__name__}(sig)')
        
        # plt.scatter(mus, np.gradient(func(mus, sig0, *args), mus), alpha=0.2, label=f'{i} mu')
        # plt.scatter(sigs, np.gradient(func(mu0, sigs, *args), sigs), alpha=0.2, label=f'{i} sig')
        # plt.plot(mus, dmu_func(mus, sig0, *args), label=f'{i} mu')
        # plt.plot(sigs, dsig_func(mu0, sigs, *args), label=f'{i} sig')
        
        # plt.plot(mus, np.abs((np.gradient(func(mus, sig0, *args), mus) - dmu_func(mus, sig0, *args))), label=f'{i} mu')
        # plt.plot(sigs, np.abs((np.gradient(func(mu0, sigs, *args), sigs) - dsig_func(mu0, sigs, *args))), '--',label=f'{i} sig')
    plt.vlines([np.sqrt(mu0/k)], [0], [1], 'k', label='coarsening sigma')
    if log_y:
        plt.yscale('log')
    plt.ylim(1e-8, 1e0)
    plt.title('Relative errrors of various functions')
    plt.legend()
    plt.grid()
    plt.show()

# Define sliders and checkboxes
kappa_slider = widgets.FloatSlider(value=1, min=0.1, max=5, step=0.1, description='kappa')
k_slider = widgets.FloatSlider(value=1, min=0.1, max=5, step=0.1, description='k')
eps_slider = widgets.FloatSlider(value=0.0, min=0., max=0.1, step=0.001, description='eps')
lbd_spl_slider = widgets.FloatSlider(value=7, min=0.1, max=10, step=0.1, description='lbd_spl')
r_slider = widgets.FloatSlider(value=1, min=0.1, max=5, step=0.1, description='r')
mu_slider = widgets.FloatSlider(value=4, min=0.1, max=50, step=0.1, description='mu')
sig_slider = widgets.FloatSlider(value=3, min=0.1, max=12, step=0.1, description='sig')
log_y_toggle = widgets.ToggleButton(value=True, description='Log y-axis', button_style='')

# Create interactive plot
interactive_plot = interactive(plot_functions, 
                               sig=sig_slider, 
                               kappa=kappa_slider, 
                               k=k_slider, 
                               eps=eps_slider, 
                               lbd_spl=lbd_spl_slider, 
                               r=r_slider,
                               mu0=mu_slider,
                               sig0=sig_slider,
                               log_y=log_y_toggle)

display(interactive_plot)
# Out:
# Warning: Cannot change to a different GUI toolkit: widget. Using notebook instead.
# interactive(children=(FloatSlider(value=1.0, description='kappa', max=5.0, min=0.1), FloatSlider(value=1.0, de…

# %%
# find fold bifurcation
from scipy.optimize import fsolve
from tqdm import tqdm
from MFKSGaussClosure import *
# given Drho, Dc, T, and 2 of (r, eps, lbd_spl) find the remaining one where fold happens
# fold <=> equil. & |DF| = 0
def Df_eq(mu, sig, kappa, k, eps, lbd_spl, r):
    args = (mu, sig, kappa, k, eps, lbd_spl, r)
    return np.abs(dmu_f1(*args) * dsig_f2(*args) - dmu_f2(*args) * dsig_f1(*args))
    
# define function of 3 variables (mu, sig, lbd_spl)
def fold_bif_func_lbd_spl(x, *args):
    mu, sig, lbd_spl = x
    kappa, k, eps, r = args
    return [f1(mu, sig, kappa, k, eps, lbd_spl, r),
           f2(mu, sig, kappa, k, eps, lbd_spl, r),
           Df_eq(mu, sig, kappa, k, eps, lbd_spl, r)]    

try: # load the range if it exists 
    1/0
    result_fold_lbd_spl_epsilon_range = np.load('result_fold_lbd_spl_epsilon_range.npy', allow_pickle=True)
except:
    # find a 'good point'
    Drho = 0.1
    Dc = 1.0
    T = 5.0
    epsilon = 1e-6
    r = 1e-3
    kappa, k, eps, _, r = reparameterize(Drho, Dc, T, epsilon, r)
    full_sol = fsolve(func=fold_bif_func_lbd_spl, 
                       x0=[38.5, 5.3, 70.0],
                       args=(kappa, k, eps, r),
                       full_output=1)
    good_point_lbd_spl = full_sol[0]

    # extend to 'very' large epsilon range
    n_epsilon = 10000
    epsilon_range = np.logspace(-6, -1, n_epsilon)
    result_fold_lbd_spl_epsilon_range = np.empty((n_epsilon, 3), dtype=object)
    prev_sol = good_point_lbd_spl
    for i, epsilon in tqdm(enumerate(epsilon_range), desc = f'{full_sol[-1]}'):
        kappa, k, eps, _, r = reparameterize(Drho, Dc, T, epsilon, r)
        full_sol = fsolve(func=fold_bif_func_lbd_spl, 
                           x0=prev_sol,
                           args=(kappa, k, eps, r),
                           full_output=1)
        prev_sol = full_sol[0]
        result_fold_lbd_spl_epsilon_range[i] = [prev_sol[0], prev_sol[1], (kappa, k, eps, prev_sol[2], r)]

    np.save('result_fold_lbd_spl_epsilon_range.npy', result_fold_lbd_spl_epsilon_range)

if False: # plot
    import matplotlib.pyplot as plt
    # %matplotlib notebook
    fig, ax = plt.subplots()
    ax.plot(epsilon_range, result_fold_lbd_spl_epsilon_range[:, 0], 'o-', label='fold bifurcation')
    ax.grid()
    ax.legend()
    ax.set_xscale('log')
    plt.show()

try: # load if it works
    result_fold_lbd_spl_r_range = np.load('result_fold_lbd_spl_r_range.npy', allow_pickle=True)    
except:
    # find a 'good point'
    Drho = 0.1
    Dc = 1.0
    T = 5.0
    epsilon = 1e-6
    r = 1e-9
    kappa, k, eps, _, r = reparameterize(Drho, Dc, T, epsilon, r)
    full_sol = fsolve(func=fold_bif_func_lbd_spl, 
                       x0=[39.5, 5.5, 57.0],
                       args=(kappa, k, eps, r),
                       full_output=1)
    good_point_lbd_spl = full_sol[0]

    # extend to 'very' large r range
    n_r = 10000
    r_range = np.logspace(-9, -1, n_r)
    result_fold_lbd_spl_r_range = np.empty((n_r, 3), dtype=object)
    prev_sol = good_point_lbd_spl
    for i, r in tqdm(enumerate(r_range), desc = f'{full_sol[-1]}'):
        kappa, k, eps, _, r = reparameterize(Drho, Dc, T, epsilon, r)
        full_sol = fsolve(func=fold_bif_func_lbd_spl, 
                           x0=prev_sol,
                           args=(kappa, k, eps, r),
                           full_output=1)
        prev_sol = full_sol[0]
        result_fold_lbd_spl_r_range[i] = [prev_sol[0], prev_sol[1], (kappa, k, eps, prev_sol[2], r)]

    np.save('result_fold_lbd_spl_r_range.npy', result_fold_lbd_spl_r_range)

if False: # plot
    import matplotlib.pyplot as plt
    # %matplotlib notebook
    fig, ax = plt.subplots()
    ax.plot(r_range, result_fold_lbd_spl_r_range[:, 0], 'o-', label='fold bifurcation')
    ax.grid()
    ax.legend()
    ax.set_xscale('log')
    plt.show()
# Out:
# The solution converged.: 10000it [01:31, 108.79it/s]

# %%
# want to explore fold_lbd_spl_epsilon_range at any r

# for a given r, find closest values in result_fold_lbd_spl_r_range and use as initial condition to expand to all epsilon_range
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook
from scipy.special import erf
from ipywidgets import interactive, widgets
from IPython.display import display

# Function to plot
def plot_functions(n_epsilon, r, log_y):
    Drho = 0.1
    Dc = 1.0
    T = 5.0
    epsilon_range = np.logspace(-6, -1, n_epsilon)
    _result_fold_lbd_spl_epsilon_range = np.empty((n_epsilon, 3), dtype=object)
    full_sol = result_fold_lbd_spl_epsilon_range[np.argmin(np.abs(r-np.array([result_fold_lbd_spl_epsilon_range[i][-1][-1] for i in range(n_epsilon)])))]
    prev_sol = [full_sol[0], full_sol[1], full_sol[2][3]]
    for i, epsilon in enumerate(epsilon_range):
        print(f'{i} / {n_epsilon}, {full_sol[-1]}', end='\r', flush=True)
        kappa, k, eps, _, r = reparameterize(Drho, Dc, T, epsilon, r)
        full_sol = fsolve(func=fold_bif_func_lbd_spl, 
                           x0=prev_sol,
                           args=(kappa, k, eps, r),
                           full_output=1)
        prev_sol = full_sol[0]
        _result_fold_lbd_spl_epsilon_range[i] = [prev_sol[0], prev_sol[1], (kappa, k, eps, prev_sol[2], r)]
    
    plt.figure(figsize=(10, 6))
    plt.plot(epsilon_range, [_result_fold_lbd_spl_epsilon_range[i][-1][3] for i in range(n_epsilon)], '-o',label='lbd_spl - fold')
    
    if log_y:
        plt.yscale('log')
        
    plt.legend()
    plt.xscale('log')
    plt.xlabel('epsilon')
    plt.ylabel('Function Value')
    plt.title('Interactive Plot of Functions')
    plt.grid(True)
    plt.show()

# Define sliders and checkboxes
n_epsilon_slider = widgets.IntSlider(value=1000, min=100, max=10000, step=100, continuous_update=False, description='n_epsilon')
r_slider = widgets.FloatLogSlider(value=1e-3, base=10, min=-5, max=-1, step=0.1, readout_format='.2e', continuous_update=False, description='r')
log_y_toggle = widgets.ToggleButton(value=False, description='Log y-axis', button_style='')

# Create interactive plot
interactive_plot = interactive(plot_functions, 
                               n_epsilon=n_epsilon_slider,
                               r=r_slider,
                               log_y=log_y_toggle)

display(interactive_plot)
# Out:
# interactive(children=(IntSlider(value=1000, continuous_update=False, description='n_epsilon', max=10000, min=1…

# %%
# find transcritical bifurcation of sigma dynamics

# given Drho, Dc, T, and 2 of (r, eps, lbd_spl) find the remaining one where fold happens
# fold <=> sigma-equil. & dsig_F2 = 0 & dmu_F2 = 0
# define function of 3 variables (mu, sig, param)
def transcrit_bif_func_lbd_spl(x, *args):
    mu, sig, lbd_spl = x
    kappa, k, eps, r = args
    return [F2(mu, sig, kappa, k, eps, lbd_spl, r),
           dsig_f2(mu, sig, kappa, k, eps, lbd_spl, r) - sig * f1(mu, sig, kappa, k, eps, lbd_spl, r) + 0.5 * (mu**2 - sig**2) * dsig_f1(mu, sig, kappa, k, eps, lbd_spl, r),
            dmu_f2(mu, sig, kappa, k, eps, lbd_spl, r) + mu  * f1(mu, sig, kappa, k, eps, lbd_spl, r) + 0.5 * (mu**2 - sig**2) * dmu_f1(mu, sig, kappa, k, eps, lbd_spl, r)]

# # define good initial guess
# def transcrit_bif_func_lbd_spl_ini(*args):
#     kappa, k, eps, r = args
#     return [27.0, 1.8, 38.0]

# kappa, k, eps, _, r = reparameterize(0.1, 1.0, 5.0, 1e-6, 4e-2)

# # use fsolve 
# full_sol = fsolve(func=transcrit_bif_func_lbd_spl, 
#                    x0=transcrit_bif_func_lbd_spl_ini(kappa, k, eps, r),
#                    args=(kappa, k, eps, r),
#                    full_output=1)
# prev_sol = full_sol[0]
# mu_transcrit_range = [] 
# sig_transcrit_range = [] 
# params_transcrit_range = []
# for epsilon in tqdm(np.logspace(-6, -2, 1000), desc = f'{full_sol[-1]}'):
#     kappa, k, eps, _, r = reparameterize(0.1, 1.0, 5.0, epsilon, 4e-2)
#     full_sol = fsolve(func=transcrit_bif_func_lbd_spl, 
#                        x0=prev_sol,
#                        args=(kappa, k, eps, r),
#                        full_output=1,)
    
#     prev_sol = full_sol[0]
#     mu_transcrit_range.append(prev_sol[0])
#     sig_transcrit_range.append(prev_sol[1])
#     params_transcrit_range.append((kappa, k, eps, prev_sol[2], r))
    
try: # load the range if it exists 
    1/0
    result_transcrit_lbd_spl_epsilon_range = np.load('result_transcrit_lbd_spl_epsilon_range.npy', allow_pickle=True)
except:
    # find a 'good point'
    Drho = 0.1
    Dc = 1.0
    T = 5.0
    epsilon = 1e-6
    r = 1e-3
    kappa, k, eps, _, r = reparameterize(Drho, Dc, T, epsilon, r)
    full_sol = fsolve(func=transcrit_bif_func_lbd_spl, 
                       x0=[27.0, 1.9, 37.0],
                       args=(kappa, k, eps, r),
                       full_output=1)
    print(full_sol[-1])
    good_point_lbd_spl = full_sol[0]

    # extend to 'very' large epsilon range
    n_epsilon = 10000
    epsilon_range = np.logspace(-6, -1, n_epsilon)
    result_transcrit_lbd_spl_epsilon_range = np.empty((n_epsilon, 3), dtype=object)
    prev_sol = good_point_lbd_spl
    for i, epsilon in enumerate(epsilon_range):
#         print(f'{i} / {n_epsilon}, {full_sol[-1]}', end='\r', flush=True)
        kappa, k, eps, _, r = reparameterize(Drho, Dc, T, epsilon, r)
        full_sol = fsolve(func=transcrit_bif_func_lbd_spl, 
                           x0=prev_sol,
                           args=(kappa, k, eps, r),
                           full_output=1)
        prev_sol = full_sol[0]
        result_transcrit_lbd_spl_epsilon_range[i] = [prev_sol[0], prev_sol[1], (kappa, k, eps, prev_sol[2], r)]

    np.save('result_transcrit_lbd_spl_epsilon_range.npy', result_transcrit_lbd_spl_epsilon_range)

if True: # plot
    import matplotlib.pyplot as plt
    # %matplotlib notebook
    fig, ax = plt.subplots()
    ax.plot(epsilon_range, result_transcrit_lbd_spl_epsilon_range[:, 0], 'o-', label='transcrit bifurcation mu')
    ax.plot(epsilon_range, result_transcrit_lbd_spl_epsilon_range[:, 1], 'o-', label='transcrit bifurcation sig')
    ax.plot(epsilon_range, [result_transcrit_lbd_spl_epsilon_range[i, 2][3] for i in range(n_epsilon)], 'o-', label='transcrit bifurcation sig')
    ax.grid()
    ax.legend()
    ax.set_xscale('log')
    plt.show()
# Out:
# The solution converged.
# <img src="data:image/png;base64,..." width="640">

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook

fig, ax = plt.subplots()
ax.plot([result_fold_lbd_spl_epsilon_range[i][-1][2] for i in range(len(result_fold_lbd_spl_epsilon_range))], [result_fold_lbd_spl_epsilon_range[i][-1][3] for i in range(len(result_fold_lbd_spl_epsilon_range))], 'o-', label='fold bifurcation')
# ax.plot([result_fold_lbd_spl_epsilon_range[i][-1][2] for i in range(len(result_fold_lbd_spl_epsilon_range))], [result_fold_lbd_spl_epsilon_range[i][0] for i in range(len(result_fold_lbd_spl_epsilon_range))], 'o-', label='fold bifurcation - mu')
ax.plot([result_transcrit_lbd_spl_epsilon_range[i][-1][2] for i in range(len(result_transcrit_lbd_spl_epsilon_range))], [result_transcrit_lbd_spl_epsilon_range[i][-1][3] for i in range(len(result_transcrit_lbd_spl_epsilon_range))], 'o-', label='transcrit bifurcation')
# stability of trivial equilibria
epsilon_array = np.logspace(-6, -2, 50)
kappa_array, k_array, eps_array, lbd_spl_array, r_array = reparameterize(0.1, 1.0, 5.0, epsilon_array, 4e-2)
lower_stab_array = -1/k_array * np.log(eps_array / k_array / kappa_array)
ax.plot(eps_array, lower_stab_array, label='lower stability bound')
# ax.plot(eps_array, lbd_spl_array, label='lbd_spl')
# ax.fill_between(eps_array, lbd_spl_array, lower_stab_array, where=lower_stab_array<lbd_spl_array, color='k', alpha=0.3, label='stability region')
ax.grid()
ax.legend()
ax.set_xscale('log')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# approx functions (old)
from MFKSGaussClosure import gauss, erfc
def g_avg_approx(mu, sig, kappa, k, eps, lbd_spl, r):
    mu_tilde = mu - k * sig**2
    return kappa * np.exp((mu_tilde**2 - mu**2) / 2 / sig**2) + eps * mu

def lbd_g_avg_approx(mu, sig, kappa, k, eps, lbd_spl, r):
    mu_tilde = mu - k * sig**2
    return (kappa * np.exp((mu_tilde**2 - mu**2) / 2 / sig**2) * (sig**2 * gauss(mu_tilde, sig) + mu_tilde) +
            eps * (sig**2 + mu**2))

def rate_avg_approx(mu, sig, kappa, k, eps, lbd_spl, r):
    # return r * sig / np.sqrt(2 * np.pi) - r / 2 * (lbd_spl - mu) + r / np.sqrt(2 * np.pi) * (lbd_spl - mu)**2 / 2 / sig
    return r * np.maximum(mu - lbd_spl, 0)

    # return r * (np.maximum(0, -(lbd_spl - mu)) + np.exp(-np.sqrt(2*np.pi*(lbd_spl - mu)**2)/2) / np.sqrt(2 * np.pi)) 

def lbd2_rate_avg_approx(mu, sig, kappa, k, eps, lbd_spl, r):
    return r * (sig**2 * (2 * sig**2 + mu**2) * gauss(lbd_spl - mu, sig) + 
                (mu**2 * (mu - lbd_spl) + sig**2 * (3 * mu - lbd_spl)) * erfc((lbd_spl - mu) / sig))

# %%
from matplotlib.colors import LogNorm, ListedColormap
def create_transparent_cmap(cmap_name, alpha_vals):
    base_cmap = plt.get_cmap(cmap_name)
    base_colors = base_cmap(np.arange(base_cmap.N))

    new_colors = np.zeros_like(base_colors)
    for i, alpha in enumerate(alpha_vals):
        new_colors[i, :] = np.append(base_colors[i, :3], alpha)
    return ListedColormap(new_colors)

# Define alpha values for transparency (0 to 1)
alpha_vals = np.linspace(0, 1, 256)

# Create custom colormap with transparency
transparent_cmap = create_transparent_cmap('Blues', alpha_vals)

# %%
# terms by order of magnitude
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm, SymLogNorm
# %matplotlib widget
from matplotlib.widgets import Slider
from ipywidgets import interact, FloatSlider
from MFKSGaussClosure import mu_sig_prime, mu_prime, sig_prime
from scipy.integrate import solve_ivp

def sig_term1(mu, sig, kappa, k, eps, lbd_spl, r):
    eps = 0.0
    lbd_spl = np.inf
    r = 0.0
    args = (mu, sig, kappa, k, eps, lbd_spl, r)
    mu_tilde = mu - k * sig**2
    return kappa * k * sig * np.exp(-k * mu + k**2 * sig**2 / 2) * erfc(- mu_tilde / sig) - eps * sig

def sig_term2(mu, sig, kappa, k, eps, lbd_spl, r):
    eps = 0.0
    lbd_spl = np.inf
    r = 0.0
    args = (mu, sig, kappa, k, eps, lbd_spl, r)
    mu_tilde = mu - k * sig**2
    return sig * gauss(*args) * (eps * mu * (1 + mu**2/sig**2) / 2 + kappa * np.exp(-k * mu + k**2 * sig**2 / 2) * erfc(- mu_tilde / sig) * (1/2 + k * sig**2 / mu + mu**2/sig**2/2) - kappa * (1 + mu**2/sig**2)/2)

def sig_term_eps(mu, sig, kappa, k, eps, lbd_spl, r):
    lbd_spl = np.inf
    r = 0.0
    args = (mu, sig, kappa, k, eps, lbd_spl, r)
    mu_tilde = mu - k * sig**2
    return - eps * sig + sig * gauss(*args) * (eps * mu * (1 + mu**2/sig**2) / 2)

# def sig_term_r1(mu, sig, kappa, k, eps, lbd_spl, r):
#     eps = 0.0
#     args = (mu, sig, kappa, k, eps, lbd_spl, r)
#     res = - 1/8 * lbd2_rate_avg(*args)
#     return res / sig
def sig_term_r1(mu, sig, kappa, k, eps, lbd_spl, r):
    eps = 0.0
    args = (mu, sig, kappa, k, eps, lbd_spl, r)
    res1 = ((mu**2 + sig**2) * rate_avg(mu, sig, kappa, k, eps, lbd_spl, r) + 
            2 * r * mu * sig**2 * erfc((lbd_spl - mu) / sig) / erfc(- mu / sig) + 
            r * sig**4 * gauss(lbd_spl - mu, sig) / erfc(- mu / sig) )
    res2 = r * sig**2 * gauss(lbd_spl - mu, sig) / erfc(- mu / sig) - r * (lbd_spl - mu) * erfc((lbd_spl - mu) / sig) / erfc(- mu / sig)
    res3 = 0.25 * mu**2 * rate_avg(*args) / sig
    return - res1 / 8 / sig - res2 * sig / 4 + res3

# def sig_term_r2(mu, sig, kappa, k, eps, lbd_spl, r):
#     eps = 0.0
#     args = (mu, sig, kappa, k, eps, lbd_spl, r)
#     res = 0.5 * (mu**2 - sig**2) * (0.5 * rate_avg(*args))
#     return res / sig
    
def sig_term_r2(mu, sig, kappa, k, eps, lbd_spl, r):
    eps = 0.0
    args = (mu, sig, kappa, k, eps, lbd_spl, r)
    res = 0.25 * mu**2 * rate_avg(*args)
    return res / sig
    



def plot_functions(kappa, k, eps, lbd_spl, r, funcs_to_plot):
    # Create a grid of points
    x = np.linspace(0, 100, 1000)
    y = np.linspace(0.001, 10, 1000)
    X, Y = np.meshgrid(x, y)
    mask = X - 2*Y < 0

    args = (kappa, k, eps, lbd_spl, r)

    plt.close('all')
    plt.figure(figsize=(10, 6))

    mynorm = SymLogNorm(1e-7, vmin=-1e1, vmax=1e1)
    if 'sig_term1' in funcs_to_plot:
        strm = plt.pcolormesh(x, y, sig_term1(X, Y, *args), cmap='bwr', norm=mynorm)
    if 'sig_term2' in funcs_to_plot:
        strm = plt.pcolormesh(x, y, sig_term2(X, Y, *args), cmap='bwr', norm=mynorm)
    if 'sig_term_eps' in funcs_to_plot:
        strm = plt.pcolormesh(x, y, sig_term_eps(X, Y, *args), cmap='bwr', norm=mynorm)
    if 'sig_term_r1' in funcs_to_plot:
        strm = plt.pcolormesh(x, y, sig_term_r1(X, Y, *args), cmap='bwr', norm=mynorm)
    if 'sig_term_r2' in funcs_to_plot:
        strm = plt.pcolormesh(x, y, sig_term_r2(X, Y, *args), cmap='bwr', norm=mynorm)
        
    plt.colorbar(strm)
    plt.xlim(np.min(x),np.max(x))
    plt.ylim(np.min(y),np.max(y))
    plt.xlabel('mu')
    plt.ylabel('sig')
    plt.grid()
    plt.tight_layout()
    plt.show()

# Define sliders and checkboxes
kappa_slider = widgets.FloatSlider(value=1, min=0.1, max=5, step=0.1, description='kappa', continuous_update=False)
k_slider = widgets.FloatSlider(value=1, min=0.1, max=5, step=0.1, description='k', continuous_update=False)
eps_slider = widgets.FloatSlider(value=1e-6, min=0., max=1e-2, step=1e-6, readout_format='.1e',description='eps', continuous_update=False)
lbd_spl_slider = widgets.FloatSlider(value=50, min=0.1, max=100, step=1, description='lbd_spl', continuous_update=False)
r_slider = widgets.FloatSlider(value=1, min=0.0, max=5, step=0.1, description='r', continuous_update=False)
funcs_checkboxes = widgets.SelectMultiple(
    options=['sig_term1', 'sig_term2', 'sig_term_eps', 'sig_term_r1', 'sig_term_r2'],
    value=['sig_term1'],
    description='Functions'
)

# Create interactive plot
interactive_plot = interactive(plot_functions, 
                               mu=mu_slider, 
                               sig=sig_slider, 
                               kappa=kappa_slider, 
                               k=k_slider, 
                               eps=eps_slider, 
                               lbd_spl=lbd_spl_slider, 
                               r=r_slider, 
                               funcs_to_plot=funcs_checkboxes
            )

display(interactive_plot)

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
# %matplotlib widget
from matplotlib.widgets import Slider
from ipywidgets import interact, FloatSlider
from MFKSGaussClosure import mu_sig_prime, mu_prime, sig_prime, erfc, gauss
from scipy.integrate import solve_ivp
from scipy.optimize import fsolve

# Function to create the streamline plot
def plot_func(Drho, Dc, T, epsilon, r):
    # Create a grid of points
    x = np.linspace(0, 10000, 1000)
    kappa, k, eps, lbd_spl, r = reparameterize(Drho, Dc, T, epsilon, r)

    sig_prime
    
    
    # Create the plot
    fig = plt.figure(figsize=(10, 8))
    plt.plot(x, [fsolve(lambda y: sig_prime(xi, y, kappa, k, eps, lbd_spl, r), np.sqrt(xi/k)) for xi in x], 'o-')
    plt.plot(x, [fsolve(lambda y: 2 * k * y**3 * erfc(-(xi - k * y**2) / y) / gauss((xi - k * y**2) / y) + - k * y**2 - xi**2, np.sqrt(xi/k)) for xi in x], 'o-')

    plt.plot(x, np.sqrt(x / k), 'k--')

    x, y = MFKSGaussClosure.get_traj(10, 2.8, kappa, k, eps, lbd_spl, r, 1e3)
    plt.plot(x, y)
    plt.xscale('log')
    plt.yscale('log')
    plt.xlabel('mu')
    plt.title('Streamline plot of the vector field')
    plt.grid()
    plt.tight_layout()
    plt.show()

# Interactive sliders
# Define sliders and checkboxes
Drho_slider = FloatSlider(value=0.1, min=0.01, max=1.0, step=0.01, description='D_rho:', layout=Layout(width='500px'), continuous_update=False)
Dc_slider = FloatSlider(value=1.0, min=0.1, max=2.0, step=0.1, description='D_c:', layout=Layout(width='500px'), continuous_update=False)
T_slider = FloatSlider(value=5.0, min=0.5, max=10.0, step=0.1, description='T:', layout=Layout(width='500px'), continuous_update=False)
epsilon_slider = FloatSlider(value=0, min=0, max=1e-1, step=1e-4, description='epsilon:', readout_format='.2e', layout=Layout(width='500px'), continuous_update=False)
r_slider = FloatSlider(value=0.04, min=0.001, max=1.0, step=1e-3, description='r:', readout_format='.1e', layout=Layout(width='500px'), continuous_update=False)

# Create interactive plot
interactive_plot = interactive(plot_func, 
                               Drho=Drho_slider,
                               Dc=Dc_slider,
                               T=T_slider,
                               epsilon=epsilon_slider,
                               r=r_slider)

display(interactive_plot)
# Out:
# interactive(children=(FloatSlider(value=0.1, continuous_update=False, description='D_rho:', layout=Layout(widt…

# %%
import re
import numpy as np
a = []
with open("/scratch/n/Natan.Dominko/comsol_cluster/logistic_peak_stat/job.log", 'r') as f:
    for i,line in enumerate(f):
        valid = re.compile(r"[0-9]")
        if re.match(valid, line[0]):
            a.append(float(line.split()[2]))
            # print()
        if i > 10000000:
            break
a = np.array(a)
print(len(a))
# Out:
# 2777409

# %%
from scipy.signal import find_peaks
for k in [1, 5, 10, 50, 100, 500]:
    print(len(find_peaks(np.convolve(a, np.ones(k)/k, 'same'))[0]))
# Out:
# 21620
# 20755
# 19376
# 19328
# 18925
# 19989

# %%
k = 50
b = find_peaks(np.convolve(a, np.ones(k)/k, 'same'))[0]
fig, ax = plt.subplots(1, figsize=(8,5))
ax.hist((b[1:]-b[:-1]), 30)
ax.grid()
ax.set_yscale('log')
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pde_sol_rho = pde_sol[0,0,:,:]

import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation

# Animation function
def animate(i):
    plt.cla()
    plt.plot(h5file.x_range, pde_sol_rho[i,:])
    plt.title(f'Time: {h5file.t_range[i]:.2f}')
    plt.xlabel('x')
    plt.ylabel('u')
    plt.xlim(0.0, h5file.xmax)
    plt.ylim(np.min(pde_sol_rho[-1,:]), np.max(pde_sol_rho[-1,:]))

# Create animation
fig = plt.figure(figsize=(15,10))
ani = FuncAnimation(fig, animate, frames=h5file.nt, interval=50)
ani.save('animation.gif', writer='imagemagick', fps=10)# Display animation
# plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# stability of trivial equilibria
fig, ax = plt.subplots()
epsilon_array = np.logspace(-4, -1, 50)
kappa_array, k_array, eps_array, lbd_spl_array, r_array = reparameterize(0.1, 1.0, 5.0, epsilon_array, 4e-2)
lower_stab_array = -1/k_array * np.log(eps_array / k_array / kappa_array)
ax.plot(epsilon_array, lower_stab_array, label='lower stability bound')
ax.plot(epsilon_array, lbd_spl_array, label='lbd_spl')
ax.fill_between(epsilon_array, lbd_spl_array, lower_stab_array, where=lower_stab_array<lbd_spl_array, color='k', alpha=0.3, label='stability region')
ax.set_xscale('log')
ax.set_yscale('log')
ax.grid()
ax.legend()
plt.tight_layout()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# streamline + nullclines, epsilon dependence investigation 
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
# %matplotlib widget
from matplotlib.widgets import Slider
from ipywidgets import interact, FloatSlider
from MFKSGaussClosure import mu_sig_prime, mu_prime, sig_prime
from scipy.integrate import solve_ivp
from scipy.optimize import fsolve


def plot_vector_field(Drho, Dc, T, epsilon):
    # Create a grid of points
    # x = np.linspace(29, 33, 100)
    x = np.linspace(0, 40, 100)
    # y = np.linspace(4, 6, 100)
    y = np.linspace(0.001, 6, 100)
    X, Y = np.meshgrid(x, y)
    r = 0.0
    kappa, k, eps, lbd_spl, r = reparameterize(Drho, Dc, T, epsilon, r)
    U, V = mu_sig_prime((X, Y), kappa, k, eps, lbd_spl, r)
    
    print(f"µ∞ = {kappa/eps:.1e} (location of µ nullcline")
    mu0 = -1/k * np.log(eps/k/kappa)
    print(f"µ0 = {mu0:.2f} (maximum of v_M)")    

    
    # Create the plot
    fig, ax = plt.subplots(1, figsize=(10, 8))
    strm = ax.streamplot(X, Y, U, V, color=np.sqrt(U**2 + V**2), density=1.6, cmap='winter', norm=LogNorm(1e-16, 1e-1))
    fig.colorbar(strm.lines)
    scatter_flex(fig, ax, x, [find_roots_rich(lambda y: sig_prime(xi, y, kappa, k, eps, lbd_spl, r), y, ()) for xi in x], label='$\sigma\' = 0, \epsilon > 0$')
    scatter_flex(fig, ax, x, [find_roots_rich(lambda y: y**2 * k * erfc(-(xi-k*y**2)/y)/gauss(xi-k*y**2, y) - 0.5*(xi**2 + y**2) + eps/kappa * y**2 * xi * (y**2/xi**2 + 1) - y**2 * eps / kappa / gauss(xi, y), y, ()) for xi in x], label='$\sigma\' = 0, \epsilon > 0$ (approx)')

    ax.plot(mu0 + k * y**2 / 2, y, 'r--', label='$\mu = \mu_0 + k \sigma^2 / 2$')
    # plt.plot(mu0 + k * y**2 / 2 - y / (mu0 - 0.5 * k * y**2) / k, y, 'r--', label='new nullcline + corr')
    
    eps = 0.0
    scatter_flex(fig, ax, x, [find_roots_rich(lambda y: sig_prime(xi, y, kappa, k, eps, lbd_spl, r), y, ()) for xi in x], label='$\sigma\' = 0, \epsilon = 0$')
    scatter_flex(fig, ax, x, [find_roots_rich(lambda y: y**2 * k * erfc(-(xi-k*y**2)/y)/gauss(xi-k*y**2, y) - 0.5*(xi**2 + y**2) + eps/kappa * y**2 * xi * (y**2/xi**2 + 1) - y**2 * eps / kappa / gauss(xi, y), y, ()) for xi in x], label='$\sigma\' = 0, \epsilon = 0$ (approx)')
        
    # plt.plot(np.sqrt(np.pi/2) * y + k * y**2, y, 'k--')
    ax.plot(x, np.sqrt(x/k), 'k--', label='$\mu = k \sigma^2$')
    ax.set_xlim(np.min(x),np.max(x))
    ax.set_ylim(np.min(y),np.max(y))
    ax.legend(loc='upper left')
    ax.set_xlabel('mu')
    ax.set_ylabel('sig')
    ax.set_title('Streamline plot of the vector field')
    ax.grid()
    plt.tight_layout()
    plt.show()

# Interactive sliders
# Define sliders and checkboxes
Drho_slider = FloatSlider(value=0.1, min=0.01, max=1.0, step=0.01, description='D_rho:', layout=Layout(width='500px'), continuous_update=False)
Dc_slider = FloatSlider(value=1.0, min=0.1, max=2.0, step=0.1, description='D_c:', layout=Layout(width='500px'), continuous_update=False)
T_slider = FloatSlider(value=5.0, min=0.5, max=10.0, step=0.1, description='T:', layout=Layout(width='500px'), continuous_update=False)
epsilon_slider = FloatSlider(value=1e-4, min=0, max=1e0, step=1e-4, description='epsilon:', readout_format='.2e', layout=Layout(width='500px'), continuous_update=False)

# Create interactive plot
interactive_plot = interactive(plot_vector_field, 
                               Drho=Drho_slider,
                               Dc=Dc_slider,
                               T=T_slider,
                               epsilon=epsilon_slider)

display(interactive_plot)
# Out:
# interactive(children=(FloatSlider(value=0.1, continuous_update=False, description='D_rho:', layout=Layout(widt…

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
# %matplotlib widget
from matplotlib.widgets import Slider
from ipywidgets import interact, FloatSlider, Layout, interactive
from MFKSGaussClosure import mu_sig_prime, mu_prime, sig_prime, lbd2_rate_avg, rate_avg, erfc, gauss
from scipy.integrate import solve_ivp
from scipy.optimize import fsolve


# Function to create the streamline plot
def plot_vector_field(Drho, Dc, T, epsilon, lbd_spl, r):
    # Create a grid of points
    # x = np.linspace(29, 33, 100)
    x = np.linspace(0, 40, 100)
    # y = np.linspace(4, 6, 100)
    y = np.linspace(0.001, 6, 100)
    X, Y = np.meshgrid(x, y)
    kappa, k, eps, _, r = reparameterize(Drho, Dc, T, epsilon, r)
    U, V = mu_sig_prime((X, Y), kappa, k, eps, lbd_spl, r)
    
    print(f"µ∞ = {kappa/eps:.1e} (location of µ nullcline")
    mu0 = -1/k * np.log(eps/k/kappa)
    print(f"µ0 = {mu0:.2f} (maximum of v_M)")    


    # Create the plot
    fig, ax = plt.subplots(1, figsize=(10, 8))
    strm = ax.streamplot(X, Y, U, V, color=np.sqrt(U**2 + V**2), density=1.6, cmap='winter', norm=LogNorm(1e-16, 1e-1))
    fig.colorbar(strm.lines)
    scatter_flex(fig, ax, x, [find_roots_rich(lambda y: sig_prime(xi, y, kappa, k, eps, lbd_spl, r), y, ()) for xi in x], label='$\sigma\' = 0, \epsilon > 0$')
    scatter_flex(fig, ax, x, [find_roots_rich(lambda y: y**2 * k * erfc(-(xi-k*y**2)/y)/gauss(xi-k*y**2, y) - 0.5*(xi**2 + y**2) + eps/kappa * y**2 * xi * (y**2/xi**2 + 1) - y**2 * eps / kappa / gauss(xi, y), y, ()) for xi in x], label='$\sigma\' = 0, \epsilon > 0$ (approx)')

    ax.plot(mu0 + k * y**2 / 2, y, 'r--', label='$\sigma\' = 0$ (analytic approx)')#'$\mu = \mu_0 + k \sigma^2 / 2$')
    # plt.plot(mu0 + k * y**2 / 2 - y / (mu0 - 0.5 * k * y**2) / k, y, 'r--', label='new nullcline + corr')
    
    eps = 0.0
    scatter_flex(fig, ax, x, [find_roots_rich(lambda y: sig_prime(xi, y, kappa, k, eps, lbd_spl, r), y, ()) for xi in x], label='$\sigma\' = 0, \epsilon = 0$')
    scatter_flex(fig, ax, x, [find_roots_rich(lambda y: y**2 * k * erfc(-(xi-k*y**2)/y)/gauss(xi-k*y**2, y) - 0.5*(xi**2 + y**2) + eps/kappa * y**2 * xi * (y**2/xi**2 + 1) - y**2 * eps / kappa / gauss(xi, y), y, ()) for xi in x], label='$\sigma\' = 0, \epsilon = 0$ (approx)')

    scatter_flex(fig, ax, [fsolve(lambda x: mu_prime(x, yi, kappa, k, eps, lbd_spl, r), k*yi**2) for yi in y], y, label='$\mu\' = 0$')
    scatter_flex(fig, ax, [fsolve(lambda x: mu_prime(x, yi, kappa, k, 0.0, lbd_spl, r), k*yi**2) for yi in y], y, marker='+', label='$\mu\' = 0 (\epsilon = 0)$')
    
    _x = 2 * y**2 / lbd_spl**2
    ax.plot(lbd_spl/2 * (1 + _x * np.log(4 * kappa/_x/r/y**2))/(1 + _x), y, 'r--', label='$\mu\' = 0$ (analytic approx)')
    # ax.plot(lbd_spl/np.sqrt(2) * (1 + 1.5*y**2/lbd_spl**2), y, 'blue')
        
    # plt.plot(np.sqrt(np.pi/2) * y + k * y**2, y, 'k--')
    ax.plot(x, np.sqrt(x/k), 'k--', label='$\mu = k \sigma^2$')
    ax.set_xlim(np.min(x),np.max(x))
    ax.set_ylim(np.min(y),np.max(y))
    ax.legend(loc='upper left')
    ax.set_xlabel('mu')
    ax.set_ylabel('sig')
    ax.set_title('Streamline plot of the vector field')
    ax.grid()
    plt.tight_layout()
    plt.show()

# Interactive sliders
# Define sliders and checkboxes
Drho_slider = FloatSlider(value=0.1, min=0.01, max=1.0, step=0.01, description='D_rho:', layout=Layout(width='500px'), continuous_update=False)
Dc_slider = FloatSlider(value=1.0, min=0.1, max=2.0, step=0.1, description='D_c:', layout=Layout(width='500px'), continuous_update=False)
T_slider = FloatSlider(value=5.0, min=0.5, max=10.0, step=0.1, description='T:', layout=Layout(width='500px'), continuous_update=False)
epsilon_slider = FloatSlider(value=1e-6, min=0, max=1e-3, step=1e-6, description='epsilon:', readout_format='.2e', layout=Layout(width='500px'), continuous_update=False)
lbd_spl_slider = FloatSlider(value=3e1, min=0, max=1e2, step=1, description='lbd_spl:', readout_format='.2e', layout=Layout(width='500px'), continuous_update=False)
r_slider = FloatSlider(value=1e-6, min=0, max=1e-1, step=1e-6, description='r:', readout_format='.1e', layout=Layout(width='500px'), continuous_update=False)

# Create interactive plot
interactive_plot = interactive(plot_vector_field, 
                               Drho=Drho_slider,
                               Dc=Dc_slider,
                               T=T_slider,
                               epsilon=epsilon_slider,
                               lbd_spl=lbd_spl_slider,
                               r=r_slider)

display(interactive_plot)
# Out:
# interactive(children=(FloatSlider(value=0.1, continuous_update=False, description='D_rho:', layout=Layout(widt…

# %%
import numpy as np
def get_matr(N):
    A = np.zeros((N,N))
    for i in range(N):
        if i < N-1:
            A[i, i+1] -= 1
            A[i, i] += 1
        if i > 0:
            A[i, i-1] -= 1
            A[i, i] += 1
    return A
        
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
for N in [100, 10, 7, 5, 3]:
    ax.plot(np.linspace(0, 1-1/N, N), np.sort(np.linalg.eigvals(get_matr(N))) - 2*(1 - np.cos(np.pi*np.linspace(0, 1-1/N, N))), 'o-')

# %% [markdown]
# ## Trash
